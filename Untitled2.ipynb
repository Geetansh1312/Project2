# %%
import fetch_stock_data as fsd
import numpy as np
import pandas as pd
list=fsd.sdata()

# %%
list
# Out:
#          DATE SERIES    OPEN    HIGH     LOW  PREV. CLOSE     LTP   CLOSE  \
# 0  2023-03-29     EQ  509.00  518.00  506.30       508.10  517.00  516.50
# 1  2023-03-28     EQ  511.45  511.75  503.85       510.15  509.00  508.10
# 2  2023-03-27     EQ  507.00  514.15  501.55       505.35  509.00  510.15
# 3  2023-03-24     EQ  514.50  514.95  503.45       512.75  505.50  505.35
# 4  2023-03-23     EQ  519.40  521.00  511.50       521.55  512.00  512.75
# ..        ...    ...     ...     ...     ...          ...     ...     ...
# 56 2023-01-06     EQ  607.40  607.45  597.00       605.10  601.00  600.65
# 57 2023-01-05     EQ  607.00  611.60  601.95       605.20  605.75  605.10
# 58 2023-01-04     EQ  611.85  614.95  604.00       612.40  605.60  605.20
# 59 2023-01-03     EQ  614.50  616.60  610.00       612.20  612.95  612.40
# 60 2023-01-02     EQ  614.95  619.20  611.20       613.70  612.60  612.20
#
#       VWAP   52W H  52W L    VOLUME         VALUE  NO OF TRADES SYMBOL
# ...

# %%
list.isnull().sum()
# Out:
# DATE            0
# SERIES          0
# OPEN            0
# HIGH            0
# LOW             0
# PREV. CLOSE     0
# LTP             0
# CLOSE           0
# VWAP            0
# 52W H           0
# 52W L           0
# VOLUME          0
# VALUE           0
# NO OF TRADES    0
# SYMBOL          0
# dtype: int64

# %%
data = [
    {
        "Name": "John Smith",
        "Age": 32,
        "Gender": "Male",
        "Country": "USA",
        "Salary": 5000
    },
    {
        "Name": "Emily Johnson",
        "Age": 28,
        "Gender": "Female",
        "Country": "UK",
        "Salary": 4500
    },
    {
        "Name": "Robert Lee",
        "Age": 45,
        "Gender": "Male",
        "Country": "USA",
        "Salary": 6000
    },
    {
        "Name": "Emma Davis",
        "Age": None,
        "Gender": "Female",
        "Country": None,
        "Salary": 4000
    },
    {
        "Name": "Michael Chen",
        "Age": 37,
        "Gender": None,
        "Country": "China",
        "Salary": 5500
    }
]

# %%
data=pd.DataFrame(data)

# %%
dat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dat
#
# NameError: name 'dat' is not defined

# %%
data
# Out:
#             Name   Age  Gender Country  Salary
# 0     John Smith  32.0    Male     USA    5000
# 1  Emily Johnson  28.0  Female      UK    4500
# 2     Robert Lee  45.0    Male     USA    6000
# 3     Emma Davis   NaN  Female    None    4000
# 4   Michael Chen  37.0    None   China    5500

# %%
data.isnull()
# Out:
#     Name    Age  Gender  Country  Salary
# 0  False  False   False    False   False
# 1  False  False   False    False   False
# 2  False  False   False    False   False
# 3  False   True   False     True   False
# 4  False  False    True    False   False

# %%
data.isnull().sum()
# Out:
# Name       0
# Age        1
# Gender     1
# Country    1
# Salary     0
# dtype: int64

# %%
mv=['None','NaN',np.nan]
